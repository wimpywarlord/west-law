# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./MergedOutput.csv')

# %%
# Extract year information
df['Year'] = df['TREATED CASE DATE'].str.extract(r'(\d{4})')

df.head()
# Out:
#                                 DOCUMENT INFORMATION  \
# 0  Supreme Court of Alabama. September 29, 2000 7...
# 1  Supreme Court of Alabama. June 02, 2000 775 So...
# 2  Supreme Court of Alabama. May 26, 2000 774 So....
# 3  Supreme Court of Alabama. November 17, 2000 78...
# 4  Supreme Court of Alabama. March 10, 2000 775 S...
#
#                             PRIMARY CASE INFORMATION PRIMARY CASE DATE STATE  \
# 0  U.S. Diagnostic, Inc. v. Shelby Radiology, P.C...     Sep. 29, 2000  Ala.
# 1  Ex parte Land, No. 1971816, 775 So. 2d 847, 20...     June 02, 2000  Ala.
# 2  Southern Energy Homes, Inc. v. Gary, No. 19722...      May 26, 2000  Ala.
# 3  Mock v. Allen, No. 1980985, 783 So. 2d 828, 20...     Nov. 17, 2000  Ala.
# 4  Sisters of Visitation v. Cochran Plastering Co...     Mar. 10, 2000  Ala.
#
#       TREATMENT                           TREATED CASE INFORMATION  \
# 0  Overruled by   1.  Bruce v. Cole \n854 So.2d 47 , Ala. , (NO...
# 1  Overruled by   1.  State v. Martin \n69 So.3d 94 , Ala. , (N...
# 2  Overruled by      1.  Jim Burke Automotive, Inc. v. McGrue  ...
# 3  Abrogated by   1.  Ex parte Vanderwall  \n201 So.3d 525 , Al...
# 4  Abrogated by   1.  Citizens Bank v. Alafabco, Inc. \n123 S.C...
#
#   TREATED CASE DATE  Year
# 0     Jan. 24, 2003  2003
# 1     Jan. 07, 2011  2011
# 2     Jan. 18, 2002  2002
# 3     Sep. 30, 2015  2015
# 4     June 02, 2003  2003

# %%
# Group occurrences based on year
df["Count"] = df.groupby('Year').size().reset_index(name='Occurrences')
grouped_df = df.groupby('Year').size().reset_index(name='Occurrences')

# Display the result
print(grouped_df)
# Out:
#      Year  Occurrences
# 0    1798            1
# 1    1804            1
# 2    1809            1
# 3    1812            1
# 4    1819            1
# ..    ...          ...
# 197  2019          304
# 198  2020          253
# 199  2021          151
# 200  2022          150
# 201  2023          161
#
# [202 rows x 2 columns]

# %%
# Convert 'Year' column to numeric
grouped_df['Year'] = pd.to_numeric(grouped_df['Year'])

# Sort DataFrame by 'Year'
grouped_df = grouped_df.sort_values(by='Year')

# Plot bar graph
plt.figure(figsize=(10, 6))
plt.bar(grouped_df['Year'], grouped_df['Occurrences'], color='skyblue')
plt.title('Occurrences of Cases by Year')
plt.xlabel('Year')
plt.ylabel('Occurrences')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot line chart
plt.figure(figsize=(10, 6))
plt.plot(grouped_df['Year'], grouped_df['Occurrences'], marker='o', color='green', linestyle='-')
plt.title('Occurrences of Cases Over Years')
plt.xlabel('Year')
plt.ylabel('Occurrences')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
